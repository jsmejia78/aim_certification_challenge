# %% [markdown]
# # Prototyping Notebook
#
# Prototyping for data loading, retrievals and evals

# %%
from dotenv import load_dotenv
import os
from uuid import uuid4

load_dotenv()

assert os.getenv("OPENAI_API_KEY"), "Missing OPENAI_API_KEY"
assert os.getenv("TAVILY_API_KEY"), "Missing TAVILY_API_KEY"
assert os.getenv("LANGCHAIN_API_KEY"), "Missing LANGCHAIN_API_KEY"
assert os.getenv("COHERE_API_KEY"), "Missing COHERE_API_KEY"

langsmith_api_key = os.getenv("LANGCHAIN_API_KEY")

os.environ["LANGCHAIN_TRACING_V2"] = "true"
langsmith_project_name = "AIM-CERT-LANGGRAPH-PARENT"
os.environ["LANGCHAIN_PROJECT"] = langsmith_project_name
print(langsmith_project_name)

MODE = "PIPE-ADV"

from langgraph_agent import LangGraphAgent, RetrievalEnums

Agent = LangGraphAgent(retriever_mode=RetrievalEnums.PARENT_DOCUMENT, 
                       MODE=MODE, 
                       langchain_project_name= langsmith_project_name)
# Out:
# AIM-CERT-LANGGRAPH-PARENT

# %% [markdown]
# # Load Eval Golden Dataset

# %%
from pathlib import Path
import pickle

with open(f"eval_golden_dataset.pkl", "rb") as f:
    golden_dataset = pickle.load(f)

# %% [markdown]
# # Evaluations

# %%
import copy
import pickle
from langchain_openai import ChatOpenAI
from ragas.llms import LangchainLLMWrapper
from ragas import EvaluationDataset
from ragas import evaluate as evaluate_ragas, RunConfig
from ragas.metrics import (
    LLMContextPrecisionWithReference,
    LLMContextRecall,
    ContextEntityRecall,
    Faithfulness,
    ResponseRelevancy
    )
import numpy as np
import pickle
import prompts
import importlib
importlib.reload(prompts)

skip_evaluation = []

eval_full_results = {}
eval_summary_results = {}
eval_langsmith_raw_results = {}
eval_langsmith_summary_results = {}

# Prepare dataset for this chain
golden_dataset_active_copy = copy.deepcopy(golden_dataset)

count = 0
# Generate responses for evaluation
for test_row in golden_dataset_active_copy:

    print(f"user input: {test_row.eval_sample.user_input}")
    
    response = await Agent.chat(test_row.eval_sample.user_input + "Use your RAG tool or web search tool to get context to asnwer my question")
    
    Agent.reset_longer_term_memory()

    test_row.eval_sample.response = response["response"]

    count += 1
    for source in ["rag", "search"]:
        for context in response["context"].get(source, []):
            if hasattr(context, "page_content"):
                print(f"{count} - {source} - type: {type(context)}")
            else:
                print(f"{count} {source} - type: {type(context)}")
                     
    # Merge context from RAG and search
    test_row.eval_sample.retrieved_contexts = [
        context.page_content if hasattr(context, "page_content") else context
        for source in ["rag", "search"]
        for context in response["context"].get(source, [])
    ]

evaluation_active_dataset = EvaluationDataset.from_pandas(golden_dataset_active_copy.to_pandas())
evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini"))

custom_run_config = RunConfig(timeout=600)

# Run evaluation using only RETRIEVAL metrics
print("Running RAGAS evaluation...")
eval_result_active = evaluate_ragas(
    dataset=evaluation_active_dataset,
    metrics=[LLMContextPrecisionWithReference(), LLMContextRecall(), ContextEntityRecall(), Faithfulness(), ResponseRelevancy()],
    llm=evaluator_llm,
    run_config=custom_run_config
)

eval_full_resultsc= eval_result_active

# Convert to DataFrames and compute statistics
df_eval_result_active = eval_result_active.to_pandas()
eval_result_active_means = df_eval_result_active.mean(numeric_only=True)
eval_result_active_stds = df_eval_result_active.std(numeric_only=True)

eval_summary_results = {
    "means": eval_result_active_means,
    "stds": eval_result_active_stds
}

print(f"RAGAS Results for pipeline with baseline retrieval:")
print(eval_result_active_means)
print(eval_result_active_stds)

# save results to pickle in case of errors or crashes
pickle_agent_baseline_ragas_results = { 
    "raw_results": eval_result_active, 
    "summary_results": eval_summary_results }

# Save to file
with open(f"cert_agent_eval_ragas_results_for_baseline_retrieval.pkl", "wb") as f:
    pickle.dump(pickle_agent_baseline_ragas_results, f)
# Out:
# user input: How can parents help their child develop the executive function skills of the prefrontal cortex?
# 1 rag - type: <class 'str'>
# user input: Howw can I help my child develup their prefrontal cortex?
# 2 rag - type: <class 'str'>
# user input: Wut shud I do if my kid keeps forgeting the permision slip?
# 3 rag - type: <class 'str'>
# user input: Why children under age ten not hear me when I talk, even if I say it loud?
# 4 rag - type: <class 'str'>
# user input: How can using a hand puppet help encourage cooperation from an older child when preparing for a new sibling?
# 5 rag - type: <class 'str'>
# user input: Why children need to learn about trust and how come it important for them to feel safe in the world, and what should I do about children seeing scary things on TV?
# 6 rag - type: <class 'str'>
# user input: What I supposed to do when Isaac come home from religious school and say God want him to hurt someone, like in that Abraham and Isaac story?
# 7 rag - type: <class 'str'>
# user input: How can the experiences of parenting a toddler inform strategies for maintaining a strong bond with a preteen?
# 8 rag - type: <class 'str'>
# user input: Wut are the problums with using Power-based punishment for preteens, and why shud I try other stratagies?
# 9 rag - type: <class 'str'>
# user input: How I supposed to help boys when they act all tough and like they don’t care, but really they sensitive, and what dads or uncles supposed to do for boys so they grow up good?
# 10 rag - type: <class 'str'>
# user input: What does Ms. Frizzle say about encouraging creativity in children?
# 11 rag - type: <class 'str'>
# user input: How Mom help kid do art stuff good?
# 12 rag - type: <class 'str'>
# user input: Wut shud I do if my kid uses bad wurds on Instagram?
# 13 rag - type: <class 'str'>
# user input: Wut shud I do if Mrs. Brown says my kid was smokin in the backyard?
# 14 rag - type: <class 'str'>
# user input: How can a parnt help their child feel herd and suported when talking about feelings?
# 15 rag - type: <class 'str'>
# user input: How Pete show he connect if he not talk much?
# 16 rag - type: <class 'str'>
# user input: what i do when preschooler mad bout new baby
# 17 rag - type: <class 'str'>
# user input: As a parent preparing for a second child, how can I encourage originality and individuality in my older child while also serving as a positive role model, especially in situations that require moral courage?
# 18 rag - type: <class 'str'>
# user input: As a parent preparing for a second child, how can I use active listening and empathy in communication to help my older child express their feelings about the new sibling, and what practical strategies from the context can I apply to ensure my child feels heard and supported during this transition?
# 19 rag - type: <class 'str'>
# user input: Wut r sum foolproof stratgies for encouragin children to talk and use positive communiction, especally when they dont respond at first?
# 20 rag - type: <class 'str'>
# user input: How can gradual familiarization with a designated caregiver help ease a child's adjustment to the arrival of a new baby, and what specific strategies can parents use to foster a positive sibling relationship during this transition?
# 21 rag - type: <class 'str'>
# user input: how i help my kid be more creative and what i do with art supplies to help?
# 22 rag - type: <class 'str'>
# user input: How can gentle weaning practices help a child adjust to school, considering both the emotional transition away from breastfeeding and the need for new sources of comfort and connection?
# 23 rag - type: <class 'str'>
# user input: how i make my toddler feel more independent and powerful, like, give them agency and empowerment, when i got a new baby coming? what i do so they not feel left out and instead feel like they can do stuff and help, and how does letting them do things around the house help with that, and why is it important for their development?
# 24 rag - type: <class 'str'>
# user input: As a parent preparing for a second child, how can I use active listening and empathy in communication to help my older child adjust to the new sibling, and what specific strategies from both deep listening and empathetic responses can foster a safe and supportive environment for my child to express their feelings during this transition?
# 25 rag - type: <class 'str'>
# user input: How can peaceful parenting strategies provide emotional support for children, especially when helping a preschooler adjust to big feelings and new routines?
# 26 rag - type: <class 'str'>
# user input: What strategies can a parent use to foster self-regulation and introduce calming strategies for children, especially when preparing for the arrival of a new sibling, and how does the use of a cozy corner support these goals according to child development experts?
# 27 rag - type: <class 'str'>
# user input: How can the emotional benefits of play be harnessed to encourage cooperation and teamwork among children, particularly when preparing a young child for the arrival of a new sibling, and what specific playful strategies from the context can help foster a positive sibling relationship during this transition?
# 28 rag - type: <class 'str'>
# user input: How can empathic limits in parenting help foster emotional intelligence in an older child adjusting to a new sibling?
# 29 rag - type: <class 'str'>
# user input: What are effective strategies for gaining a child's attention and ensuring they listen, especially when preparing for a new sibling, and how can concise communication help in this process?
# 30 rag - type: <class 'str'>
# user input: how sleep hygiene and making a consistent bedtime routine help with mood for both toddlers and preteens, and what problems happen if they stay up late?
# 31 rag - type: <class 'str'>
# user input: What strategies can parents use to comfort children during parental absence when a new sibling is born, and how might these approaches influence the emotional impact on siblings during the transition?
# 32 rag - type: <class 'str'>
# user input: How can a parent preparing a child for a new sibling use active listening and empathy in communication to reduce sibling rivalry and foster a positive family transition?
# 33 rag - type: <class 'str'>
# user input: How can a parent concerned about screen addiction in young children use empathy and deep listening to support their child's emotional development and foster positive sibling relationships during the transition to a new baby?
# 34 rag - type: <class 'str'>
# user input: How can 'Special Time' help a child cope with the emotional challenges of weaning, and what strategies are suggested to foster this connection during the transition?
# 35 rag - type: <class 'str'>
# user input: What strategies can parents use to help kids feel connected both to their teacher and to other kids at school, and how can these approaches support children in managing separation anxiety and building positive relationships?
# 36 rag - type: <class 'str'>
# user input: How does the use of 'time-in' as opposed to timeouts help a parent foster emotional intelligence and resilience in a child, and what role does co-regulation play in this process according to the provided context?
# 37 rag - type: <class 'str'>
# user input: How Maria help with sibling rivalry and what you do if your kid scared about new baby, like, you know, Maria was your best friend in first grade and you was nervous but then you liked school, so how you use that story and also what games or routines you do to make your kid not so worried and help them laugh, and also what if they still sad or scared, what you supposed to do, like, with Maria and all that?
# 38 rag - type: <class 'str'>
# user input: How can games like Hide and Seek or Hide and Go Seek be used to help a child cope with separation anxiety during transitions, and what additional strategies can parents and caregivers use to support a positive experience?
# 39 rag - type: <class 'str'>
# user input: how peaceful parenting help with new baby and big kid, and what Peaceful Parent, Happy Siblings book say?
# 40 rag - type: <class 'str'>
# user input: How can a comfort corner be used to help both an older child and a new sibling adjust during family transitions, and what strategies ensure that the comfort corner fosters positive associations rather than feelings of rejection?
# 41 rag - type: <class 'str'>
# user input: How can the principles of peaceful parenting, as described in 'Peaceful Parent, Happy Siblings,' help a parent prepare their child for the arrival of a new baby and foster a positive sibling relationship?
# 42 rag - type: <class 'str'>
# user input: how can i help my preschooler feel safe and less scared at bedtime, especially when they have fears like thunderstorms or being alone in the dark, and what steps can i take to support their courage and reduce bedtime anxiety?
# 43 rag - type: <class 'str'>
# user input: Why is it especially challenging for children under age ten to listen and respond to parents, and what specific strategies can parents use to improve communication with children in this age group, considering the effects of background noise and brain development?
# 44 rag - type: <class 'str'>
# user input: How can a mom help her toddler adjust to sleeping independently at night while also fostering a positive sibling relationship and addressing feelings of jealousy, as described in the context?
# 45 rag - type: <class 'str'>
# user input: How can Play-Doh be used to encourage creative art play and help children adjust to a new sibling?
# 46 rag - type: <class 'str'>
# user input: Drawing on the principles of Peaceful Parenting and the specific strategies outlined in 'Peaceful Parenting Your Preteen,' how can a parent like Emma Carter foster a positive transition for her young child when preparing for the arrival of a new sibling, particularly in terms of reducing sibling rivalry and maintaining a strong parent-child bond during emotionally challenging moments?
# 47 rag - type: <class 'str'>
# user input: how i make big kid not scared when new baby come, like in peaceful parent happy siblings book?
# 48 rag - type: <class 'str'>
# user input: As a parent preparing a young child for the arrival of a new sibling, how can the principles of peaceful parenting—such as staying connected, engaging cooperation with empathy, and establishing routines—be applied to foster a positive sibling relationship and ease the transition for your growing family? Please provide specific strategies that incorporate these peaceful parenting themes.
# 49 rag - type: <class 'str'>
# user input: how peaceful parenting help me with my 7 year old when new baby come, like what steps i do to keep things calm and stop fighting, and what are the big ideas of peaceful parenting?
# 50 rag - type: <class 'str'>
# user input: How can using a cozy corner support co-regulation and help children develop emotional intelligence during times of upset?
# 51 rag - type: <class 'str'>
# Running RAGAS evaluation...
# Evaluating:   0%|          | 0/255 [00:00<?, ?it/s]
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('400 Client Error: Bad Request for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Bad request: invalid \'dotted_order\': dotted_order 0b4111ca-af62-40cf-a21a-19099987b317 has timestamp 2025-08-05 00:54:10.675723 +0000 UTC earlier than parent timestamp 2025-08-05 00:54:10.766729 +0000 UTC for run_id:0b4111ca-af62-40cf-a21a-19099987b317 trace_id:efe179c7-c613-4742-9c53-f32f93b3c680 dotted_order:20250805T005355831184Zefe179c7-c613-4742-9c53-f32f93b3c680.20250805T005355840995Z862be9bf-f87d-48ed-bb28-7636fdb47415.20250805T005410766729Z0915dfa3-67f6-4e8a-9efe-3d4502a5b5c8.20250805T005410675723Z0b4111ca-af62-40cf-a21a-19099987b317 parent_run_id:0915dfa3-67f6-4e8a-9efe-3d4502a5b5c8"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('400 Client Error: Bad Request for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Bad request: invalid \'dotted_order\': dotted_order 0b4111ca-af62-40cf-a21a-19099987b317 has timestamp 2025-08-05 00:54:10.675723 +0000 UTC earlier than parent timestamp 2025-08-05 00:54:10.766729 +0000 UTC for run_id:c1e82711-7dbf-45e1-92aa-4ccbb58158cc trace_id:efe179c7-c613-4742-9c53-f32f93b3c680 dotted_order:20250805T005355831184Zefe179c7-c613-4742-9c53-f32f93b3c680.20250805T005355840995Z862be9bf-f87d-48ed-bb28-7636fdb47415.20250805T005410766729Z0915dfa3-67f6-4e8a-9efe-3d4502a5b5c8.20250805T005410675723Z0b4111ca-af62-40cf-a21a-19099987b317.20250805T005410677748Zc1e82711-7dbf-45e1-92aa-4ccbb58158cc parent_run_id:0b4111ca-af62-40cf-a21a-19099987b317"}\n')
# Exception raised in Job[197]: LLMDidNotFinishException(The LLM generation was not completed. Please increase try increasing the max_tokens and try again.)
# RAGAS Results for pipeline with baseline retrieval:
# llm_context_precision_with_reference    1.000000
# context_recall                          0.887185
# context_entity_recall                   0.280423
# faithfulness                            0.909620
# answer_relevancy                        0.953455
# dtype: float64
# llm_context_precision_with_reference    1.121270e-16
# context_recall                          1.931860e-01
# context_entity_recall                   3.457222e-01
# faithfulness                            1.325187e-01
# answer_relevancy                        2.673450e-02
# dtype: float64

# %% [markdown]
# Visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def create_barplot_with_error(eval_summary_results, strategy_name="Baseline Naive"):
    """
    Create a bar plot showing evaluation metrics for a single strategy,
    with error bars representing standard deviation and legend outside the plot.
    """
    # Define metric keys and display labels
    metrics = [
        'llm_context_precision_with_reference',
        'context_recall',
        'context_entity_recall',
        'faithfulness',
        'answer_relevancy'
    ]
    metric_labels = [
        'Context Precision',
        'Context Recall',
        'Entity Recall',
        'Faithfulness',
        'Answer Relevancy'
    ]
    
    # Extract means and stds
    means = eval_summary_results["means"]
    stds = eval_summary_results["stds"]

    # Prepare data
    data = []
    for metric, label in zip(metrics, metric_labels):
        data.append({
            "Metric": label,
            "Mean": means[metric],
            "Std": stds[metric],
            "Strategy": strategy_name
        })

    # Create DataFrame
    df = pd.DataFrame(data)

    # Plot setup
    plt.figure(figsize=(14, 6))  # wider to accommodate external legend
    ax = plt.gca()
    sns.barplot(
        data=df,
        x="Metric",
        y="Mean",
        hue="Strategy",
        ax=ax,
        capsize=0.1,
        dodge=False,
        width=0.5,
        ci=None  # Manual error bars
    )

    # Manually centered error bars
    bar_container = ax.containers[0]
    for bar, row in zip(bar_container, df.itertuples()):
        x = bar.get_x() + bar.get_width() / 2
        ax.errorbar(
            x, row.Mean, yerr=row.Std,
            fmt='none', c='black', capsize=5, linewidth=1.2
        )

    # Final plot formatting
    plt.title(f'Agent Pipeline Evaluation: {strategy_name}\nMean ± Std Dev', fontsize=14, fontweight='bold')
    plt.ylabel('Score')
    plt.ylim(0, 1)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # leave space on the right

    # Legend outside the plot area
    plt.legend(
        title="Retrieval Strategy",
        loc='center left',
        bbox_to_anchor=(1, 0.5),
        borderaxespad=0.5
    )

    plt.show()

    return df

# Example usage:
barplot_df = create_barplot_with_error(eval_summary_results, strategy_name="Filtered Retrieval")
# Out:
# /tmp/ipykernel_326101/677595952.py:46: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
